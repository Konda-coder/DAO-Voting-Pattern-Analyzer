# %%
import numpy as np
import pandas as pd
from tqdm import tqdm

# Data Visualization
import matplotlib.pyplot as plt
import plotly.express as px

import plotly.graph_objects as go
from plotly.subplots import make_subplots


# Data pre-processing
from sklearn.preprocessing import StandardScaler

# Data splitting
from sklearn.model_selection import train_test_split

# Machine learning Models
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier


# Evaluation metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn.metrics import roc_curve, auc


#Installing dependencies
# !pip install -U kaleido

# %%
data =  pd.read_csv("voters.csv")
data.head()

# %%
data.shape

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72539 entries, 0 to 72538
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   st_name     72539 non-null  object
#  1   year        72539 non-null  int64
#  2   pc_no       72539 non-null  int64
#  3   pc_name     72539 non-null  object
#  4   pc_type     64469 non-null  object
#  5   cand_name   72539 non-null  object
#  6   cand_sex    72539 non-null  object
#  7   partyname   72539 non-null  object
#  8   partyabbre  72539 non-null  object
#  9   totvotpoll  72539 non-null  int64
#  10  electors    72539 non-null  int64
#  11  difference  72539 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 6.6+ MB

# %%
data.describe(include = 'all')
# Out:
#               st_name          year         pc_no  pc_name pc_type  \
# count           72539  72539.000000  72539.000000    72539   64469
# unique             43           NaN           NaN      769       4
# top     Uttar Pradesh           NaN           NaN  Belgaum     GEN
# freq            14711           NaN           NaN      566   54450
# mean              NaN   1996.650836     22.336467      NaN     NaN
# std               NaN     10.364290     19.054898      NaN     NaN
# min               NaN   1977.000000      1.000000      NaN     NaN
# 25%               NaN   1989.000000      7.000000      NaN     NaN
# 50%               NaN   1996.000000     18.000000      NaN     NaN
# 75%               NaN   2004.000000     33.000000      NaN     NaN
# max               NaN   2014.000000     85.000000      NaN     NaN
#
#           cand_name cand_sex    partyname partyabbre     totvotpoll  \
# count         72539    72539        72539      72539   72539.000000
# unique        56601        3         1424       1071            NaN
# top     Ashok Kumar        M  Independent        IND            NaN
# freq             87    68885        31458      41127            NaN
# mean            NaN      NaN          NaN        NaN   50125.004921
# std             NaN      NaN          NaN        NaN  105228.965947
# min             NaN      NaN          NaN        NaN       0.000000
# 25%             NaN      NaN          NaN        NaN     864.000000
# 50%             NaN      NaN          NaN        NaN    2697.000000
# 75%             NaN      NaN          NaN        NaN   19587.500000
# max             NaN      NaN          NaN        NaN  863358.000000
#
#             electors    difference
# count   7.253900e+04  7.253900e+04
# unique           NaN           NaN
# top              NaN           NaN
# freq             NaN           NaN
# mean    1.119182e+06  1.069057e+06
# std     3.546481e+05  3.662137e+05
# min     1.947100e+04  9.871000e+03
# 25%     9.119010e+05  8.274030e+05
# 50%     1.097187e+06  1.055592e+06
# 75%     1.321399e+06  1.277222e+06
# max     3.368399e+06  3.367912e+06

# %%
data.to_excel('cleaned_voters_data.xlsx', index=False)

# %%
data_viz = data.copy()

# %%
data['pc_type'].unique()
# Out:
# array(['GEN', nan, 'ST', 'SC', 'SC '], dtype=object)
